# %% [markdown]
# <a href="https://colab.research.google.com/github/jrebull/MNA/blob/main/Serie_de_Tiempo_Javier_Rebull_A01795838.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Maestría en Inteligencia Artificial Aplicada**
#
# ## **Inteligencia Artificial y Aprendizaje Automático**
#
# ### Tecnológico de Monterrey
#
# ### Prof Luis Eduardo Falcón Morales
#
# ## **Actividad 9: Modelos de predicción con modelos recurrentes**
#
# ### Javier Rebull
# ### A01795838

# %% [markdown]
# # Objetivo:
# ##### El desarrollo de esta actividad contribuye al cumplimiento de los objetivos del tema de Aprendizaje Profundo, modelos Secuenciales o Recurrentes y Series de Tiempo.

# %% [markdown]
# # **0 - Preparando los datos**

# %%
# Omitamos los Warnings por el momento:
import warnings
warnings.filterwarnings("ignore")

# %%
#!pip freeze   # Si deseas verificar qué librerías y versiones ya tiene google-Colab preinstaladas,
               # en particular "prophet" que usaremos en este ejercicio.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error
import math

from prophet import Prophet
from statsmodels.graphics.tsaplots import month_plot, quarter_plot
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf   # gráficos de autocorrelación

# Acceso a archivos en Google Colab
from google.colab import drive  # Acceso a Google Drive desde Colab
import os  # Operaciones en el sistema de archivos

import yfinance as yf   # Importamos las bibliotecas requeridas.

# %%
ticker_symbol = 'AAPL'   # selecciona las iniciales de la compañía deseada.
data = yf.download(ticker_symbol, period='5y')   # Se indica el período y descargamos.
data.to_csv('historical_data.csv')   # Guardamos los datos
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
path = 'historical_data.csv'
df = pd.read_csv(path, header=0)
df.head()
# Out:
#                        Price           Adj Close              Close  \
# 0                     Ticker                AAPL               AAPL
# 1                       Date                 NaN                NaN
# 2  2019-11-05 00:00:00+00:00  62.202579498291016  64.28250122070312
# 3  2019-11-06 00:00:00+00:00   62.22917938232422  64.30999755859375
# 4  2019-11-07 00:00:00+00:00    62.9473876953125  64.85749816894531
#
#                 High                 Low               Open    Volume
# 0               AAPL                AAPL               AAPL      AAPL
# 1                NaN                 NaN                NaN       NaN
# 2  64.54750061035156   64.08000183105469  64.26249694824219  79897600
# 3  64.37249755859375  63.842498779296875  64.19249725341797  75864400
# 4   65.0875015258789   64.52749633789062  64.68499755859375  94940400

# %%
df.info()   # La columna que nos interesa Adj Close
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1260 non-null   object
#  1   Adj Close  1259 non-null   object
#  2   Close      1259 non-null   object
#  3   High       1259 non-null   object
#  4   Low        1259 non-null   object
#  5   Open       1259 non-null   object
#  6   Volume     1259 non-null   object
# dtypes: object(7)
# memory usage: 69.0+ KB

# %%
# Renombremos de manera estándar las columnas de fechas y valores de la
# serie de tiempo, donde además la fecha la trasnformamos a tipo datetime:

df.columns = ['ds', 'y']
df['ds']= pd.to_datetime(df['ds'])

df.head()
# Out:
#           ds    y
# 0 1949-01-01  112
# 1 1949-02-01  118
# 2 1949-03-01  132
# 3 1949-04-01  129
# 4 1949-05-01  121

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      144 non-null    datetime64[ns]
#  1   y       144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %% [markdown]
# En particular datetime64[ns] nos ayuda a representar un rango de fechas muy amplio (del año 1678 al 2262) con precisión de nanosegundos.

# %% [markdown]
# ### **Agreguemos los ajustes usuales en Series de tiempo:**

# %%
# Hagamos una copia del DataFrame df con índices temporales:
df_temp = df.copy()
df_temp.set_index('ds', inplace=True)
df_temp
# Out:
#               y
# ds
# 1949-01-01  112
# 1949-02-01  118
# 1949-03-01  132
# 1949-04-01  129
# 1949-05-01  121
# ...         ...
# 1960-08-01  606
# 1960-09-01  508
# 1960-10-01  461
# 1960-11-01  390
# 1960-12-01  432
#
# [144 rows x 1 columns]

# %%
print(df.shape)
print(df_temp.shape)
# Out:
# (144, 2)
# (144, 1)

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DatetimeIndex.html

# %%
# Ajustemos la frecuencia de los índices, para que el modelo tenga información del período en que
# se encuentran los datos:

df_temp.index  # Observamos que aquí todavía no se tiene información del argumento "freq"
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='ds', length=144, freq=None)

# %% [markdown]
# Para las opciones de "freq" ver la tabla que viene en esta liga:
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases

# %%
# Especifiquemos entonces que nuestros datos están registrados con una frecuencia mensual
# al inicio del mes (cada día 01 de cada mes):
df_temp.index.freq = 'MS'  # MS-Month-start-frequency o M=ME-Month-end-frequency

df_temp.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='ds', length=144, freq='MS')

# %%
# Particionemos en entrenamiento y prueba como DataFrames de Pandas:

train = df_temp.iloc[0:-12,:]

test = df_temp.iloc[-12:,:]   # Seleccionamos los datos del último año para predicción de Test.

# %%
train.shape
# Out:
# (132, 1)

# %%
# Gráfico con la periodicidad mensual:
train['y'].plot(title='Pasajeros mensuales', style='-b')
plt.show()

# %% [markdown]
# De este gráfico podemos observar:
#
# 1.    Que tenemos una tendencia creciente, con una estacionalidad anual muy marcada
#
# 2.   Que el modelo multiplicativo de la serie de tiempo se adaptaría mejor a uno aditivo, ya que la amplitud de la variabilidad se observa que va en aumento.

# %% [markdown]
# # **1 - Modelo ingenuo (Baseline / Persistance / Naive model)**

# %% [markdown]
# *   El modelo ingenuo simplemente hace la predicción del siguiente perídodo, repitiendo el valor del último período.
#
# *   Este modelo se utiliza en general como punto de partida para comparar todos los demás,
#
# *   Utilicemos el error RMSE (Raíz del Error Cuadrático Medio) como medida del desempeño de nuestros modelos a obtener.

# %%
test['y'].values
# Out:
# array([417, 391, 419, 461, 472, 535, 622, 606, 508, 461, 390, 432])

# %%
history = [x for x in train['y'].values]   # Definimos "history" donde de manera incremental se irán agregando registros mensuales.
predictions = list()    # Lista que contendrá las predicciones del modelo ingenuo.

for i in range(len(test['y'])):
  # Obtenemos las predicciones:
  yhat = history[-1]   # La primera vez, tomamos el último dato del Train, en las siguientes, se van agregando los datos de Test.
  predictions.append(yhat)

  # Observaciones-registros reales:
  obs = test.iloc[i]['y']   # Ahora vamos tomando los datos de Test.
  history.append(obs)  # Vamos agregando a "history" (que ya tiene todo los de Train) en cada iteración, un dato más de los de Test.
  print('>Esperado-real = %3d, Predicción = %.3f' % (obs, yhat))


# Calculamos la raíz del error cuadrático medio (RMSE):
rmse = np.sqrt(mean_squared_error(test['y'].values, predictions))
print('\nError-Modelo-Naive: RMSE: %.3f' % rmse)
# Out:
# >Esperado-real = 417, Predicción = 405.000
# >Esperado-real = 391, Predicción = 417.000
# >Esperado-real = 419, Predicción = 391.000
# >Esperado-real = 461, Predicción = 419.000
# >Esperado-real = 472, Predicción = 461.000
# >Esperado-real = 535, Predicción = 472.000
# >Esperado-real = 622, Predicción = 535.000
# >Esperado-real = 606, Predicción = 622.000
# >Esperado-real = 508, Predicción = 606.000
# >Esperado-real = 461, Predicción = 508.000
# >Esperado-real = 390, Predicción = 461.000
# >Esperado-real = 432, Predicción = 390.000
#
# Error-Modelo-Naive: RMSE: 53.152

# %% [markdown]
# #### **Este valor de predicción RMSE nos dice que en promedio el error es de aproximadamente más menos 53 pasajeros por cada predicción hecha. Este será nuestro error RMSE a mejorar.**

# %%
# Grafiquemos los resultados:

fig, ax = plt.subplots(figsize=(10, 4))
ax = plt.plot(train['y'], '-k')  # Datos de entrenamiento de 1949 a 1959 (los históricos).
ax = plt.plot(test['y'], '+b')    # Datos de prueba reales del año 1960 (los del útimo año a predecir).
ax = plt.plot(test.index, predictions, 'xr')  # Predicciones del modelo ingenuo para el último año 1960.

# %% [markdown]
# #### **Aunque pareciera que las predicciones fueron bastante exactas en el gráfico, en realidad están todas desfasadas un año.**

# %% [markdown]
# # **2 - Modelo ARIMA**

# %% [markdown]
# ### **Análisis preliminar para obtener información de la serie de tiempo y construir el modelo ARIMA(p,d,q).**
#
# *   **AR (AutoRegresivo):** El modelo se basa en la relación entre un valor actual y sus valores pasados.
#
# *   **I (Integrado):** Se refiere a la diferenciación de la serie para hacerla estacionaria, es decir, eliminar tendencias y patrones cíclicos.
#
# *   **MA (Media Móvil):** Usa el error de los valores pasados (las desviaciones entre valores predichos y observados) para corregir el valor actual.

# %% [markdown]
# ##### **Ahora veamos el gráfico de descomposición de la serie de tiempo en sus componentes de tendencia (trend), estacionalidad (stationality) y residual (residual).**

# %%
# Gráficos de descomposición estacional:
decomposition = seasonal_decompose(train['y'].resample('M').mean(), model='multiplicative')  # <<<---- Observa que el modelo es multiplicativo
fig = decomposition.plot()
fig.set_size_inches(8,6)
plt.show()

# %% [markdown]
# **Observa del gráfico de Residuos que estos están alrededor del 1, a diferencia del aditivo que usualmente están alrededor del 0.**

# %% [markdown]
# ##### **Veamos ahora estos dos gráficos que nos hablan si tenemos algún tipo de estacionalidad (i.e., periodicidad). En particular, mensual o trimestral:**

# %%
# Gráfica para detección de estacionalidad mensual:
fig = month_plot(train['y'].resample('M').mean(), ylabel='Pasajeros')
fig.set_size_inches(6,6)
plt.show()

# %%
# Si queremos graficar y detectar estacionalidad trimestral:
fig = quarter_plot(train['y'].resample('Q').mean(), ylabel='Pasajeros')
fig.set_size_inches(6,6)
plt.show()

# %% [markdown]
# ### **Gráficos de Autocorrelación (ACF) y Autocorrelación Parcial (PACF)**

# %% [markdown]
# *   Los gráficos de Autocorrelación miden la correlación entre la serie de tiempo y una versión rezagada de sí misma.
#
# *   Este tipo de correlaciones de una serie de tiempo consigo misma son llamadas "autocorrelaciones" o "correlaciones seriales".
#
# *   En el eje horizontal se muestra el valor del desfazamiento (lag) y en el eje vertical el valor de correlación de la serie desfazada y la original.
#
# *   El cono sombreado indica intervalos de confianza de la correlación, con un 95% de confianza de manera predeterminada.
#
# *   Que existan autocorrelaciones significativas en estos gráficos nos habla de que la serie de tiempo no es aleatoria.
#
# *   En estos dos gráficos (llamados en inglés "pollipop plots") hay que determinar cuántos de estos lollipops están afuera del intervalo de confianza (sin contar el inicial) antes de que entre el siguiente a la zona celeste?
#
# *   **Gráfico ACF:** Muestra la correlación total entre la serie y sus retardos, incluyendo efectos directos e indirectos.
#
# *   **Gráfico PACF:** Muestra la correlación directa entre la serie y sus retardos, eliminando los efectos de los retardos intermedios.

# %%
# Gráfico de Autocorrelación (ACF: Auto-Correlation-Function)
fig,ax = plt.subplots(figsize = (6,4))
plot_acf(train['y'], lags=60, ax=ax)   # Eliges el número de unidades (meses) desfasadas. El número de "lags" es el número
plt.show()                          # que define la partición en el eje horizontal. El área no sombreada nos habla de
                                    # la cantidad de períodos de tiempo hacia atrás cuya información proporcionada es
                                    # significativa para la predicción futura.
                                    # También nos ayuda a detectar periodicidades, como en este caso que se observa a 13 meses, aprox.

# %% [markdown]
# El gráfico inicia con desfase (lag) de 0, lo cual es la correlación de la serie de tiempo consigo misma, la cual es 1.
#
# Posteriormente se muestran las correlaciones de la serie de tiempo original, con la serie desfasada "q" lugares hacia atrás, es decir, de orden "q" en la componente MA de ARIMA(p,d,q).
#
# **El gráfico ACF nos dice en primera instancia que la componente MA de ARIMA(p,d,q) tiene un grado "q" de 13 (en la práctica se puede buscar de 0 a 13).**

# %%
# Gráfico de Autocorrelación Parcial (PACF):
fig, ax = plt.subplots(figsize = (6,4))
plot_pacf(train['y'], lags = 60, ax = ax, method="ols")   # ols: regression of time series on lags of it an on constant. predetrminado method="ywm"
plt.show()

# %% [markdown]
# * PACF también inicia con la correlación de la serie de tiempo consigo misma, por ello el valor de 1.
#
# *   **De este gráfico podemos observar que la componente AR de ARIMA(p,d,q) tiene grado p=3 o tal vez 5 (en la práctica se puede probar de 0 a 5.)**

# %% [markdown]
# ##### Existe un buen número de librerías para el caso de pronósticos con los modelos ARIMA-SARIMA. Usaremos en este ejercicio la de Statsmodels, cuya documentación encuentras en la siguiente liga:
#
# https://www.statsmodels.org/stable/generated/statsmodels.tsa.arima.model.ARIMA.html

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
# Lo primero es para quitar la estacionalidad y transformar un problema
# de tipo no-estacionario (SARIMA) en uno estacionario (ARIMA):

# Diferencia de datos consecutivos en el tiempo
# y podemos ahora usar ARIMA:
def difference(dataset, interval=1):
  diff = list()

  for i in range(interval, len(dataset)):
    value = dataset[i] - dataset[i - interval]
    diff.append(value)

  return np.array(diff)



# Invierte las diferencias anteriores, es decir, nos regresa la estacionalidad:
def inverse_difference(history, yhat, interval=1):
  return yhat + history[-interval]

# %%
# Definamos la siguiente lista de registros de pasajeros en el tiempo:
history = [x for x in train.loc[:,'y'].values]   # train-ndarray : columna solo con los registros de pasajeros "y".
                               # history-list : lista con los datos del train.

predictions = list()   # Para incluir las predicciones que vaya generando el modelo.

for i in range(len(test['y'])):
  #
  months_in_year = 12
  diff = difference(history, months_in_year)    # diff-list: lista de los datos de diferencias para transformar SARIMA en ARIMA.

  # Generamos el modelo.
  model = ARIMA(diff, order=(3,0,13),) # Si aplicamos diff, entonces d=0 es aplicable.
  model_fit = model.fit(method_kwargs={'maxiter':300})  # Aumentar las iteraciones para evitar el WarningConvergence.

  yhat = model_fit.forecast()[0]   # prediccions (yhat) de cada registro, es un solo número flotante.
  yhat = inverse_difference(history, yhat, months_in_year)    # El "history" sigue siendo la lista de arriba.
                                                              # El nuevo "yhat" es cada un nuevo valor (float) de predicción.
  predictions.append(yhat)  # predictions-list : lista que se va incrementando al ir agregando cada predicción nueva.

  # Observaciones-reales:
  obs = test.iloc[i]['y']   #  cada dato es un flotante.
  history.append(obs)   #  history-list : se va incrementado a partir del Train con los registros-observaciones reales.

  print('>Esperado-real = %3d, Predicción = %.3f' % (obs, yhat))

# Error RMSE:
rmse = np.sqrt(mean_squared_error(test['y'].values, predictions))
print('\nError-Modelo-ARIMA: RMSE: %.3f' % rmse)
# Out:
# >Esperado-real = 417, Predicción = 410.709
# >Esperado-real = 391, Predicción = 393.034
# >Esperado-real = 419, Predicción = 442.983
# >Esperado-real = 461, Predicción = 422.243
# >Esperado-real = 472, Predicción = 478.103
# >Esperado-real = 535, Predicción = 538.088
# >Esperado-real = 622, Predicción = 604.590
# >Esperado-real = 606, Predicción = 618.914
# >Esperado-real = 508, Predicción = 521.592
# >Esperado-real = 461, Predicción = 447.942
# >Esperado-real = 390, Predicción = 402.009
# >Esperado-real = 432, Predicción = 431.787
#
# Error-Modelo-ARIMA: RMSE: 16.169

# %%
# Veamos su gráfico:
fig, ax = plt.subplots(figsize=(10, 4))
ax = plt.plot(train['y'], '-k')
ax = plt.plot(test['y'], '-b')
ax = plt.plot(test['y'], '+c')
ax = plt.plot(test.index, predictions, 'xr')

# %% [markdown]
# # **3 - Modelo Facebook-Meta-Prophet**

# %% [markdown]
# #### **En la liga del modelo Facebook-Prophet puedes encontrar mucho más información, además de la documentación correspondiente:**
#
# https://facebook.github.io/prophet/

# %%
# Prophet requiere que la entrada sean dos columnas, llamadas "ds" y "y".
# Les dmos esta forma usando el DataFrame "df" inicial:

train = df.iloc[0:-12,:]
test = df.iloc[-12:,:]

# %%
# Aplicamos el modelo Facebbok-Prophet a nuestros datos:

model = Prophet(seasonality_mode='multiplicative',
                yearly_seasonality=True,
                changepoint_prior_scale=10.,   # Controla la flexibilidad de la componente Trend, mayor valor mayores fluctuaciones.
                seasonality_prior_scale=18)    # Controla la estacionalidad, mayor el valor, mayor flexibilidad en la estacionalidad.
model.fit(train)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpdo8c8v42/tm4jbwzw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpdo8c8v42/dda6dav1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=236', 'data', 'file=/tmp/tmpdo8c8v42/tm4jbwzw.json', 'init=/tmp/tmpdo8c8v42/dda6dav1.json', 'output', 'file=/tmp/tmpdo8c8v42/prophet_modelvao4kstz/prophet_model-20241104071030.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:10:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:10:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Calculamos el error RMSE:

pred_FP = model.predict(test)['yhat']
rmse = np.sqrt(mean_squared_error(test['y'], pred_FP))
print('\nError-Modelo-FacebookProphet: RMSE: %.3f' % rmse)
# Out:
# Error-Modelo-FacebookProphet: RMSE: 21.928

# %%
# La librería misma nos permite obtener las predicciones con las cotas mínima
# y máxima, además de su gráfica, como se muestra a continuación:

forecast = model.predict(test)

fig, ax = plt.subplots(figsize=(10, 5))
model.plot(forecast, ax=ax)               # Las predicciones se muestran con la línea continua, junto con su región de variabilidad de la predicción.
ax = plt.plot(test['ds'], test['y'], '*r')   # Agregamos los datos de prueba (Test) con puntos rojos, para observar la diferencia.
ax = plt.plot(test['ds'], forecast['yhat'], '+c')    # Valores reales.

# %% [markdown]
# **Observamos que es algo conservador en sus predicciones, ya que se queda algo corto con las predicciones más altas y ligeramente por arriba de las predicciones más bajas.**

# %% [markdown]
# # **4 - Long Short Term Memory (LSTM)**

# %%
import tensorflow as tf

# %%
def preparando_datos(myData, myDate):

  # ++++++++ TRAIN +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

  # Los datos de entrenamiento son previos a la fecha "Date" que indiques y
  # tomarán hisotriales en este caso de 12 períodos previos.
  Train_Data = myData['y'][myData['ds'] < myDate].to_numpy()

  periodo = 12   # 12 meses al año

  Data_Train = []
  Data_Train_X = []
  Data_Train_Y = []

  for i in range(0, len(Train_Data), periodo):    # observa que va formando el Train set con historiales de 12 períodos consecutivos.
    try:
      Data_Train.append(Train_Data[i : i + periodo])
    except:
      pass


  # En ocasiones hay datos perdidos, en cuyo caso la última serie
  # de datos la eliminamos:
  if len(Data_Train[-1]) < periodo:
    Data_Train.pop(-1)


  # Hay que darle la forma (dimensionalidad) que requieren los modelos
  # de aprendizaje profundo, en particular la librería de TensorFlow:
  #     (batch_size, sequence_length, input_dimension).

  Data_Train_X = Data_Train[0 : -1]
  Data_Train_X = np.array(Data_Train_X)
  Data_Train_X = Data_Train_X.reshape((-1, periodo, 1))

  Data_Train_Y = Data_Train[1 : len(Data_Train)]
  Data_Train_Y = np.array(Data_Train_Y)
  Data_Train_Y = Data_Train_Y.reshape((-1, periodo, 1))


  # +++++++++++ TEST +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

  # Los datos de prueba (Test) son posteriores a la fecha "Date" y que es el
  # último ciclo que deseas predecir:
  Test_Data = myData['y'][myData['ds'] >= myDate].to_numpy()

  # inicialización de listas:
  Data_Test = []
  Data_Test_X = []
  Data_Test_Y = []

  for i in range(0, len(Test_Data), periodo):
    try:
      Data_Test.append(Test_Data[i : i + periodo])
    except:
      pass


  if len(Data_Test[-1]) < periodo:
    Data_Test.pop(-1)

  Data_Test_X = Data_Test[0 : -1]
  Data_Test_X = np.array(Data_Test_X)
  Data_Test_X = Data_Test_X.reshape((-1, periodo, 1))

  Data_Test_Y = Data_Test[1 : len(Data_Test)]
  Data_Test_Y = np.array(Data_Test_Y)
  Data_Test_Y = Data_Test_Y.reshape((-1, periodo, 1))


  return Data_Train_X, Data_Train_Y, Data_Test_X, Data_Test_Y

# %%
# Continuemos con el DataFrame como en Prophet:

threshold_Date = '1959-01-01'   # A partir de esta fecha se empieza a generar el Test.
                                # En este caso, el Text_X serán los 12 meses de 1959
                                # y el Test_Y serán los de 1960.

# Recuerda que la columna de fechas del DataFrame df, debe ser de tipo DateTime.
# Se generan paquetes de 12 meses. Los *_Y son los años desfasados hacia adelante
# de los *_X:

Train_X, Train_Y, Test_X, Test_Y = preparando_datos(df, threshold_Date)

# %%
# Podemos definir la manera en que el tamaño de paso (learning-rate) varíe
# en cada época. Es usual definir también algunas funciones, exponenciales,
# por ejemplo. Por el momento definamos valores constantes por intervalos:

def scheduler(epoch):

  if epoch <= 100:
    lrate = 0.05
  elif epoch <= 180:
    lrate = 0.0005
  elif epoch <=190:
    lrate = 0.00005
  else:
    lrate = (10 ** -5)

  return lrate


callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %%
def myModel():

  model = tf.keras.models.Sequential([tf.keras.layers.LSTM(20, input_shape=(12, 1), activation=tf.nn.leaky_relu, return_sequences=True),
                                      tf.keras.layers.BatchNormalization(),
                                      tf.keras.layers.Dropout(0.2),
                                      #tf.keras.layers.LSTM(20, activation=tf.nn.leaky_relu),
                                      #tf.keras.layers.BatchNormalization(),
                                      #tf.keras.layers.Dropout(0.2),

                                      tf.keras.layers.Dense(200, activation=tf.nn.leaky_relu),
                                      tf.keras.layers.Dropout(0.2),
                                      #tf.keras.layers.Dense(120, activation=tf.nn.leaky_relu),


                                      tf.keras.layers.Dense(12, activation=tf.nn.leaky_relu)
                                      ])
  return model


# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++


my_LSTM_model2 = myModel()

my_LSTM_model2.compile(optimizer=tf.keras.optimizers.Adam(),
                      loss='mse',    # función de costo "mse"
                      metrics=[tf.keras.metrics.RootMeanSquaredError()]   #  RMSE- despliega
                      )


H = my_LSTM_model2.fit(Train_X,
                       Train_Y,
                       epochs=200,
                       validation_data=(Test_X, Test_Y),
                       callbacks=[callback],

                       )



N = 50  # Para omitir los N primeros valores en la gráfica, que en ocasiones son
        # demasiado grandes los errores y no dejan apreciar las curvas de aprendizaje.

epochs = range(N+1, len(H.history["loss"]) + 1)

fig, ax2 = plt.subplots()
fig.set_figheight(5)
ax2.plot(epochs, H.history["root_mean_squared_error"][N:], label = "Training Root Mean Squared Error")
ax2.plot(epochs, H.history["val_root_mean_squared_error"][N:], label = "Validation Root Mean Squared Error")
ax2.set(xlabel = "Epochs", ylabel = "Loss-RMSE")
ax2.legend()

plt.show()
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 75246.4062 - root_mean_squared_error: 274.3108 - val_loss: 11164357.0000 - val_root_mean_squared_error: 3341.3108 - learning_rate: 0.0500
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 72143.8828 - root_mean_squared_error: 268.5961 - val_loss: 35891720.0000 - val_root_mean_squared_error: 5990.9697 - learning_rate: 0.0500
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 62717.1719 - root_mean_squared_error: 250.4340 - val_loss: 781617088.0000 - val_root_mean_squared_error: 27957.4160 - learning_rate: 0.0500
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 33984.7500 - root_mean_squared_error: 184.3495 - val_loss: 1272603776.0000 - val_root_mean_squared_error: 35673.5742 - learning_rate: 0.0500
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 12037.1768 - root_mean_squared_error: 109.7141 - val_loss: 1008556096.0000 - val_root_mean_squared_error: 31757.7715 - learning_rate: 0.0500
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 46260.4570 - root_mean_squared_error: 215.0824 - val_loss: 377685984.0000 - val_root_mean_squared_error: 19434.1445 - learning_rate: 0.0500
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 9474.2480 - root_mean_squared_error: 97.3357 - val_loss: 262499584.0000 - val_root_mean_squared_error: 16201.8389 - learning_rate: 0.0500
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 18482.7070 - root_mean_squared_error: 135.9511 - val_loss: 474993056.0000 - val_root_mean_squared_error: 21794.3359 - learning_rate: 0.0500
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 20093.3750 - root_mean_squared_error: 141.7511 - val_loss: 614167040.0000 - val_root_mean_squared_error: 24782.3945 - learning_rate: 0.0500
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 18754.1680 - root_mean_squared_error: 136.9459 - val_loss: 643307328.0000 - val_root_mean_squared_error: 25363.5039 - learning_rate: 0.0500
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 17085.0391 - root_mean_squared_error: 130.7097 - val_loss: 834419520.0000 - val_root_mean_squared_error: 28886.3203 - learning_rate: 0.0500
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 13729.6895 - root_mean_squared_error: 117.1738 - val_loss: 696782272.0000 - val_root_mean_squared_error: 26396.6328 - learning_rate: 0.0500
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 16018.3438 - root_mean_squared_error: 126.5636 - val_loss: 546868096.0000 - val_root_mean_squared_error: 23385.2109 - learning_rate: 0.0500
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 10651.7490 - root_mean_squared_error: 103.2073 - val_loss: 623417856.0000 - val_root_mean_squared_error: 24968.3379 - learning_rate: 0.0500
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 12713.2188 - root_mean_squared_error: 112.7529 - val_loss: 326019456.0000 - val_root_mean_squared_error: 18056.0098 - learning_rate: 0.0500
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 6875.6602 - root_mean_squared_error: 82.9196 - val_loss: 176922560.0000 - val_root_mean_squared_error: 13301.2236 - learning_rate: 0.0500
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 4880.6069 - root_mean_squared_error: 69.8613 - val_loss: 69289896.0000 - val_root_mean_squared_error: 8324.0557 - learning_rate: 0.0500
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 2607.5786 - root_mean_squared_error: 51.0645 - val_loss: 31988674.0000 - val_root_mean_squared_error: 5655.8530 - learning_rate: 0.0500
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 5739.4312 - root_mean_squared_error: 75.7590 - val_loss: 12782645.0000 - val_root_mean_squared_error: 3575.2825 - learning_rate: 0.0500
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 5781.1895 - root_mean_squared_error: 76.0341 - val_loss: 7642038.5000 - val_root_mean_squared_error: 2764.4238 - learning_rate: 0.0500
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 4049.6455 - root_mean_squared_error: 63.6368 - val_loss: 7594407.5000 - val_root_mean_squared_error: 2755.7952 - learning_rate: 0.0500
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 2572.8794 - root_mean_squared_error: 50.7236 - val_loss: 8011211.5000 - val_root_mean_squared_error: 2830.4084 - learning_rate: 0.0500
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 2162.9758 - root_mean_squared_error: 46.5078 - val_loss: 8089564.0000 - val_root_mean_squared_error: 2844.2158 - learning_rate: 0.0500
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 6709.4414 - root_mean_squared_error: 81.9112 - val_loss: 4643528.0000 - val_root_mean_squared_error: 2154.8848 - learning_rate: 0.0500
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 5867.4023 - root_mean_squared_error: 76.5990 - val_loss: 2334094.2500 - val_root_mean_squared_error: 1527.7743 - learning_rate: 0.0500
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 5787.5117 - root_mean_squared_error: 76.0757 - val_loss: 1740644.6250 - val_root_mean_squared_error: 1319.3350 - learning_rate: 0.0500
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 5806.8047 - root_mean_squared_error: 76.2024 - val_loss: 1564229.8750 - val_root_mean_squared_error: 1250.6918 - learning_rate: 0.0500
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 4018.3091 - root_mean_squared_error: 63.3901 - val_loss: 2021978.0000 - val_root_mean_squared_error: 1421.9628 - learning_rate: 0.0500
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 3873.6963 - root_mean_squared_error: 62.2390 - val_loss: 3790568.7500 - val_root_mean_squared_error: 1946.9384 - learning_rate: 0.0500
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1922.2274 - root_mean_squared_error: 43.8432 - val_loss: 5593384.0000 - val_root_mean_squared_error: 2365.0337 - learning_rate: 0.0500
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 3565.7791 - root_mean_squared_error: 59.7141 - val_loss: 5420513.0000 - val_root_mean_squared_error: 2328.1995 - learning_rate: 0.0500
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 1337.4086 - root_mean_squared_error: 36.5706 - val_loss: 4555986.0000 - val_root_mean_squared_error: 2134.4756 - learning_rate: 0.0500
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 2156.8132 - root_mean_squared_error: 46.4415 - val_loss: 4046053.2500 - val_root_mean_squared_error: 2011.4803 - learning_rate: 0.0500
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 3688.4404 - root_mean_squared_error: 60.7325 - val_loss: 3855778.7500 - val_root_mean_squared_error: 1963.6136 - learning_rate: 0.0500
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 3964.2478 - root_mean_squared_error: 62.9623 - val_loss: 4054611.2500 - val_root_mean_squared_error: 2013.6066 - learning_rate: 0.0500
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 3006.8020 - root_mean_squared_error: 54.8343 - val_loss: 3229627.2500 - val_root_mean_squared_error: 1797.1163 - learning_rate: 0.0500
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 1427.2020 - root_mean_squared_error: 37.7783 - val_loss: 2440321.0000 - val_root_mean_squared_error: 1562.1527 - learning_rate: 0.0500
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 2298.8181 - root_mean_squared_error: 47.9460 - val_loss: 1513552.5000 - val_root_mean_squared_error: 1230.2653 - learning_rate: 0.0500
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 1401.3591 - root_mean_squared_error: 37.4347 - val_loss: 962870.5000 - val_root_mean_squared_error: 981.2596 - learning_rate: 0.0500
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 2997.3608 - root_mean_squared_error: 54.7482 - val_loss: 813964.6875 - val_root_mean_squared_error: 902.1999 - learning_rate: 0.0500
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 973.9186 - root_mean_squared_error: 31.2077 - val_loss: 682589.6875 - val_root_mean_squared_error: 826.1899 - learning_rate: 0.0500
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1605.6812 - root_mean_squared_error: 40.0710 - val_loss: 718196.7500 - val_root_mean_squared_error: 847.4649 - learning_rate: 0.0500
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 6073.0957 - root_mean_squared_error: 77.9301 - val_loss: 469082.0312 - val_root_mean_squared_error: 684.8956 - learning_rate: 0.0500
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2168.7961 - root_mean_squared_error: 46.5703 - val_loss: 353273.0000 - val_root_mean_squared_error: 594.3677 - learning_rate: 0.0500
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 2661.9854 - root_mean_squared_error: 51.5944 - val_loss: 373096.0312 - val_root_mean_squared_error: 610.8159 - learning_rate: 0.0500
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1538.3723 - root_mean_squared_error: 39.2221 - val_loss: 490524.5938 - val_root_mean_squared_error: 700.3746 - learning_rate: 0.0500
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1910.8915 - root_mean_squared_error: 43.7137 - val_loss: 666217.0625 - val_root_mean_squared_error: 816.2212 - learning_rate: 0.0500
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 2282.6995 - root_mean_squared_error: 47.7776 - val_loss: 679407.1875 - val_root_mean_squared_error: 824.2616 - learning_rate: 0.0500
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 3146.6475 - root_mean_squared_error: 56.0950 - val_loss: 747818.1875 - val_root_mean_squared_error: 864.7648 - learning_rate: 0.0500
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 3873.6299 - root_mean_squared_error: 62.2385 - val_loss: 580887.1875 - val_root_mean_squared_error: 762.1595 - learning_rate: 0.0500
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 2809.2380 - root_mean_squared_error: 53.0022 - val_loss: 316343.0938 - val_root_mean_squared_error: 562.4438 - learning_rate: 0.0500
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 2166.1812 - root_mean_squared_error: 46.5423 - val_loss: 215494.8281 - val_root_mean_squared_error: 464.2142 - learning_rate: 0.0500
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 4820.3271 - root_mean_squared_error: 69.4286 - val_loss: 241793.9375 - val_root_mean_squared_error: 491.7255 - learning_rate: 0.0500
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 2070.7568 - root_mean_squared_error: 45.5056 - val_loss: 349924.7188 - val_root_mean_squared_error: 591.5444 - learning_rate: 0.0500
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 2549.8911 - root_mean_squared_error: 50.4964 - val_loss: 571840.8125 - val_root_mean_squared_error: 756.2016 - learning_rate: 0.0500
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 4636.6738 - root_mean_squared_error: 68.0931 - val_loss: 518605.5000 - val_root_mean_squared_error: 720.1427 - learning_rate: 0.0500
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 4543.8008 - root_mean_squared_error: 67.4077 - val_loss: 294286.2500 - val_root_mean_squared_error: 542.4816 - learning_rate: 0.0500
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2131.1167 - root_mean_squared_error: 46.1640 - val_loss: 149261.1719 - val_root_mean_squared_error: 386.3433 - learning_rate: 0.0500
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 2458.0635 - root_mean_squared_error: 49.5789 - val_loss: 93191.0234 - val_root_mean_squared_error: 305.2720 - learning_rate: 0.0500
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 3235.4170 - root_mean_squared_error: 56.8807 - val_loss: 99810.7812 - val_root_mean_squared_error: 315.9284 - learning_rate: 0.0500
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 3820.1992 - root_mean_squared_error: 61.8078 - val_loss: 168963.5625 - val_root_mean_squared_error: 411.0518 - learning_rate: 0.0500
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 3254.2542 - root_mean_squared_error: 57.0461 - val_loss: 263153.7812 - val_root_mean_squared_error: 512.9852 - learning_rate: 0.0500
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 2471.4075 - root_mean_squared_error: 49.7133 - val_loss: 365403.9688 - val_root_mean_squared_error: 604.4865 - learning_rate: 0.0500
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 3632.1511 - root_mean_squared_error: 60.2673 - val_loss: 456149.9688 - val_root_mean_squared_error: 675.3887 - learning_rate: 0.0500
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 1080.1757 - root_mean_squared_error: 32.8660 - val_loss: 479025.7812 - val_root_mean_squared_error: 692.1169 - learning_rate: 0.0500
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 2527.6526 - root_mean_squared_error: 50.2758 - val_loss: 340008.0625 - val_root_mean_squared_error: 583.1021 - learning_rate: 0.0500
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1111.2756 - root_mean_squared_error: 33.3358 - val_loss: 270664.2188 - val_root_mean_squared_error: 520.2540 - learning_rate: 0.0500
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 4571.4023 - root_mean_squared_error: 67.6121 - val_loss: 314836.2500 - val_root_mean_squared_error: 561.1027 - learning_rate: 0.0500
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 2415.0938 - root_mean_squared_error: 49.1436 - val_loss: 426592.6562 - val_root_mean_squared_error: 653.1406 - learning_rate: 0.0500
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1254.6031 - root_mean_squared_error: 35.4204 - val_loss: 515742.9062 - val_root_mean_squared_error: 718.1524 - learning_rate: 0.0500
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 1812.1362 - root_mean_squared_error: 42.5692 - val_loss: 596462.5000 - val_root_mean_squared_error: 772.3099 - learning_rate: 0.0500
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1108.8827 - root_mean_squared_error: 33.2999 - val_loss: 643485.0625 - val_root_mean_squared_error: 802.1752 - learning_rate: 0.0500
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1518.7535 - root_mean_squared_error: 38.9712 - val_loss: 583526.0000 - val_root_mean_squared_error: 763.8887 - learning_rate: 0.0500
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 3822.2695 - root_mean_squared_error: 61.8245 - val_loss: 328380.9688 - val_root_mean_squared_error: 573.0453 - learning_rate: 0.0500
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1829.6987 - root_mean_squared_error: 42.7750 - val_loss: 170073.0156 - val_root_mean_squared_error: 412.3991 - learning_rate: 0.0500
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 1248.6682 - root_mean_squared_error: 35.3365 - val_loss: 105088.1172 - val_root_mean_squared_error: 324.1730 - learning_rate: 0.0500
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 5211.6479 - root_mean_squared_error: 72.1917 - val_loss: 99667.6250 - val_root_mean_squared_error: 315.7018 - learning_rate: 0.0500
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1920.7456 - root_mean_squared_error: 43.8263 - val_loss: 99616.3750 - val_root_mean_squared_error: 315.6206 - learning_rate: 0.0500
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 2755.9556 - root_mean_squared_error: 52.4972 - val_loss: 123714.9766 - val_root_mean_squared_error: 351.7314 - learning_rate: 0.0500
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 3133.5088 - root_mean_squared_error: 55.9778 - val_loss: 135673.6250 - val_root_mean_squared_error: 368.3390 - learning_rate: 0.0500
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1391.3635 - root_mean_squared_error: 37.3010 - val_loss: 126182.8828 - val_root_mean_squared_error: 355.2223 - learning_rate: 0.0500
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 706.5598 - root_mean_squared_error: 26.5812 - val_loss: 120107.5234 - val_root_mean_squared_error: 346.5653 - learning_rate: 0.0500
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 371.8740 - root_mean_squared_error: 19.2840 - val_loss: 96617.8125 - val_root_mean_squared_error: 310.8340 - learning_rate: 0.0500
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 628.6326 - root_mean_squared_error: 25.0725 - val_loss: 75869.4062 - val_root_mean_squared_error: 275.4440 - learning_rate: 0.0500
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1260.9203 - root_mean_squared_error: 35.5094 - val_loss: 79862.3672 - val_root_mean_squared_error: 282.5993 - learning_rate: 0.0500
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1538.0891 - root_mean_squared_error: 39.2185 - val_loss: 110067.3984 - val_root_mean_squared_error: 331.7641 - learning_rate: 0.0500
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 738.7692 - root_mean_squared_error: 27.1803 - val_loss: 143261.1719 - val_root_mean_squared_error: 378.4986 - learning_rate: 0.0500
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2056.5916 - root_mean_squared_error: 45.3497 - val_loss: 147005.2656 - val_root_mean_squared_error: 383.4127 - learning_rate: 0.0500
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 960.7796 - root_mean_squared_error: 30.9964 - val_loss: 145560.5156 - val_root_mean_squared_error: 381.5239 - learning_rate: 0.0500
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1738.5958 - root_mean_squared_error: 41.6965 - val_loss: 98060.6641 - val_root_mean_squared_error: 313.1464 - learning_rate: 0.0500
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1283.4578 - root_mean_squared_error: 35.8254 - val_loss: 61714.2305 - val_root_mean_squared_error: 248.4235 - learning_rate: 0.0500
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 2120.6763 - root_mean_squared_error: 46.0508 - val_loss: 40311.5391 - val_root_mean_squared_error: 200.7773 - learning_rate: 0.0500
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 1351.0732 - root_mean_squared_error: 36.7569 - val_loss: 39928.9688 - val_root_mean_squared_error: 199.8223 - learning_rate: 0.0500
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 1553.3036 - root_mean_squared_error: 39.4120 - val_loss: 54847.9258 - val_root_mean_squared_error: 234.1963 - learning_rate: 0.0500
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 495.7507 - root_mean_squared_error: 22.2655 - val_loss: 71360.6172 - val_root_mean_squared_error: 267.1341 - learning_rate: 0.0500
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1287.9688 - root_mean_squared_error: 35.8883 - val_loss: 79749.0703 - val_root_mean_squared_error: 282.3988 - learning_rate: 0.0500
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1133.5006 - root_mean_squared_error: 33.6675 - val_loss: 58222.7930 - val_root_mean_squared_error: 241.2940 - learning_rate: 0.0500
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2447.6387 - root_mean_squared_error: 49.4736 - val_loss: 32861.9180 - val_root_mean_squared_error: 181.2786 - learning_rate: 0.0500
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 211.1350 - root_mean_squared_error: 14.5305 - val_loss: 16011.0107 - val_root_mean_squared_error: 126.5346 - learning_rate: 0.0500
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1377.4918 - root_mean_squared_error: 37.1146 - val_loss: 13359.4570 - val_root_mean_squared_error: 115.5831 - learning_rate: 0.0500
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1732.0864 - root_mean_squared_error: 41.6183 - val_loss: 15911.7031 - val_root_mean_squared_error: 126.1416 - learning_rate: 0.0500
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1155.0875 - root_mean_squared_error: 33.9866 - val_loss: 14381.5732 - val_root_mean_squared_error: 119.9232 - learning_rate: 5.0000e-04
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 588.8294 - root_mean_squared_error: 24.2658 - val_loss: 13246.2344 - val_root_mean_squared_error: 115.0923 - learning_rate: 5.0000e-04
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 751.4703 - root_mean_squared_error: 27.4130 - val_loss: 12068.4463 - val_root_mean_squared_error: 109.8565 - learning_rate: 5.0000e-04
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 1894.1688 - root_mean_squared_error: 43.5220 - val_loss: 11176.7578 - val_root_mean_squared_error: 105.7202 - learning_rate: 5.0000e-04
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 3101.0801 - root_mean_squared_error: 55.6873 - val_loss: 10509.7715 - val_root_mean_squared_error: 102.5172 - learning_rate: 5.0000e-04
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 1157.9580 - root_mean_squared_error: 34.0288 - val_loss: 9918.1426 - val_root_mean_squared_error: 99.5899 - learning_rate: 5.0000e-04
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 1603.8893 - root_mean_squared_error: 40.0486 - val_loss: 9377.0322 - val_root_mean_squared_error: 96.8351 - learning_rate: 5.0000e-04
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 1613.7280 - root_mean_squared_error: 40.1712 - val_loss: 8790.1318 - val_root_mean_squared_error: 93.7557 - learning_rate: 5.0000e-04
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 2146.0498 - root_mean_squared_error: 46.3255 - val_loss: 8336.0039 - val_root_mean_squared_error: 91.3017 - learning_rate: 5.0000e-04
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 1028.8779 - root_mean_squared_error: 32.0761 - val_loss: 8040.9048 - val_root_mean_squared_error: 89.6711 - learning_rate: 5.0000e-04
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 726.1948 - root_mean_squared_error: 26.9480 - val_loss: 7778.1304 - val_root_mean_squared_error: 88.1937 - learning_rate: 5.0000e-04
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1893.8549 - root_mean_squared_error: 43.5184 - val_loss: 7520.0562 - val_root_mean_squared_error: 86.7183 - learning_rate: 5.0000e-04
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 666.5782 - root_mean_squared_error: 25.8182 - val_loss: 7172.3950 - val_root_mean_squared_error: 84.6900 - learning_rate: 5.0000e-04
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 902.8132 - root_mean_squared_error: 30.0469 - val_loss: 6803.1929 - val_root_mean_squared_error: 82.4815 - learning_rate: 5.0000e-04
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1680.1102 - root_mean_squared_error: 40.9891 - val_loss: 6565.2446 - val_root_mean_squared_error: 81.0262 - learning_rate: 5.0000e-04
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 761.4410 - root_mean_squared_error: 27.5942 - val_loss: 6214.0288 - val_root_mean_squared_error: 78.8291 - learning_rate: 5.0000e-04
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1415.5015 - root_mean_squared_error: 37.6231 - val_loss: 6013.4336 - val_root_mean_squared_error: 77.5463 - learning_rate: 5.0000e-04
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1266.6843 - root_mean_squared_error: 35.5905 - val_loss: 5802.6172 - val_root_mean_squared_error: 76.1749 - learning_rate: 5.0000e-04
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 637.8274 - root_mean_squared_error: 25.2552 - val_loss: 5462.5645 - val_root_mean_squared_error: 73.9092 - learning_rate: 5.0000e-04
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 370.5568 - root_mean_squared_error: 19.2499 - val_loss: 5379.7397 - val_root_mean_squared_error: 73.3467 - learning_rate: 5.0000e-04
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 824.4110 - root_mean_squared_error: 28.7126 - val_loss: 5227.6958 - val_root_mean_squared_error: 72.3028 - learning_rate: 5.0000e-04
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 1053.6095 - root_mean_squared_error: 32.4594 - val_loss: 4976.0356 - val_root_mean_squared_error: 70.5410 - learning_rate: 5.0000e-04
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 545.3920 - root_mean_squared_error: 23.3536 - val_loss: 4891.4346 - val_root_mean_squared_error: 69.9388 - learning_rate: 5.0000e-04
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 920.5382 - root_mean_squared_error: 30.3404 - val_loss: 4819.6152 - val_root_mean_squared_error: 69.4234 - learning_rate: 5.0000e-04
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1206.4301 - root_mean_squared_error: 34.7337 - val_loss: 4685.9175 - val_root_mean_squared_error: 68.4538 - learning_rate: 5.0000e-04
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1072.7910 - root_mean_squared_error: 32.7535 - val_loss: 4560.8247 - val_root_mean_squared_error: 67.5339 - learning_rate: 5.0000e-04
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2197.0806 - root_mean_squared_error: 46.8730 - val_loss: 4371.2896 - val_root_mean_squared_error: 66.1157 - learning_rate: 5.0000e-04
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 2297.9490 - root_mean_squared_error: 47.9369 - val_loss: 4228.0708 - val_root_mean_squared_error: 65.0236 - learning_rate: 5.0000e-04
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 481.3123 - root_mean_squared_error: 21.9388 - val_loss: 4125.2183 - val_root_mean_squared_error: 64.2279 - learning_rate: 5.0000e-04
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 1333.2391 - root_mean_squared_error: 36.5135 - val_loss: 3967.5452 - val_root_mean_squared_error: 62.9885 - learning_rate: 5.0000e-04
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 1220.5879 - root_mean_squared_error: 34.9369 - val_loss: 3790.8103 - val_root_mean_squared_error: 61.5696 - learning_rate: 5.0000e-04
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 556.7611 - root_mean_squared_error: 23.5958 - val_loss: 3595.6663 - val_root_mean_squared_error: 59.9639 - learning_rate: 5.0000e-04
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 434.4800 - root_mean_squared_error: 20.8442 - val_loss: 3463.7881 - val_root_mean_squared_error: 58.8540 - learning_rate: 5.0000e-04
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 1546.9823 - root_mean_squared_error: 39.3317 - val_loss: 3327.6992 - val_root_mean_squared_error: 57.6862 - learning_rate: 5.0000e-04
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 704.2137 - root_mean_squared_error: 26.5370 - val_loss: 3177.2292 - val_root_mean_squared_error: 56.3669 - learning_rate: 5.0000e-04
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 759.1383 - root_mean_squared_error: 27.5525 - val_loss: 2995.7307 - val_root_mean_squared_error: 54.7333 - learning_rate: 5.0000e-04
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 771.6029 - root_mean_squared_error: 27.7777 - val_loss: 2883.6523 - val_root_mean_squared_error: 53.6996 - learning_rate: 5.0000e-04
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 965.2191 - root_mean_squared_error: 31.0680 - val_loss: 2779.5740 - val_root_mean_squared_error: 52.7217 - learning_rate: 5.0000e-04
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 756.3770 - root_mean_squared_error: 27.5023 - val_loss: 2668.9084 - val_root_mean_squared_error: 51.6615 - learning_rate: 5.0000e-04
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 570.9919 - root_mean_squared_error: 23.8954 - val_loss: 2588.5530 - val_root_mean_squared_error: 50.8778 - learning_rate: 5.0000e-04
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 681.2161 - root_mean_squared_error: 26.1001 - val_loss: 2509.7117 - val_root_mean_squared_error: 50.0970 - learning_rate: 5.0000e-04
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - loss: 774.4866 - root_mean_squared_error: 27.8296 - val_loss: 2422.2810 - val_root_mean_squared_error: 49.2167 - learning_rate: 5.0000e-04
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 655.6725 - root_mean_squared_error: 25.6061 - val_loss: 2350.2710 - val_root_mean_squared_error: 48.4796 - learning_rate: 5.0000e-04
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - loss: 418.0126 - root_mean_squared_error: 20.4454 - val_loss: 2244.0637 - val_root_mean_squared_error: 47.3716 - learning_rate: 5.0000e-04
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 746.2185 - root_mean_squared_error: 27.3170 - val_loss: 2162.3591 - val_root_mean_squared_error: 46.5012 - learning_rate: 5.0000e-04
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 1490.7046 - root_mean_squared_error: 38.6096 - val_loss: 2079.8142 - val_root_mean_squared_error: 45.6050 - learning_rate: 5.0000e-04
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 2068.6865 - root_mean_squared_error: 45.4828 - val_loss: 2023.8047 - val_root_mean_squared_error: 44.9867 - learning_rate: 5.0000e-04
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 666.3358 - root_mean_squared_error: 25.8135 - val_loss: 1947.2607 - val_root_mean_squared_error: 44.1278 - learning_rate: 5.0000e-04
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 1388.7502 - root_mean_squared_error: 37.2659 - val_loss: 1816.8916 - val_root_mean_squared_error: 42.6250 - learning_rate: 5.0000e-04
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 1110.8208 - root_mean_squared_error: 33.3290 - val_loss: 1709.0502 - val_root_mean_squared_error: 41.3407 - learning_rate: 5.0000e-04
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1590.5865 - root_mean_squared_error: 39.8822 - val_loss: 1644.8989 - val_root_mean_squared_error: 40.5574 - learning_rate: 5.0000e-04
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 1244.9232 - root_mean_squared_error: 35.2835 - val_loss: 1529.5884 - val_root_mean_squared_error: 39.1100 - learning_rate: 5.0000e-04
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 593.6591 - root_mean_squared_error: 24.3651 - val_loss: 1467.3512 - val_root_mean_squared_error: 38.3060 - learning_rate: 5.0000e-04
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 527.0540 - root_mean_squared_error: 22.9577 - val_loss: 1396.5431 - val_root_mean_squared_error: 37.3703 - learning_rate: 5.0000e-04
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 718.8229 - root_mean_squared_error: 26.8109 - val_loss: 1298.9269 - val_root_mean_squared_error: 36.0406 - learning_rate: 5.0000e-04
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1820.6295 - root_mean_squared_error: 42.6688 - val_loss: 1169.9714 - val_root_mean_squared_error: 34.2048 - learning_rate: 5.0000e-04
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 1315.5972 - root_mean_squared_error: 36.2712 - val_loss: 1048.9415 - val_root_mean_squared_error: 32.3874 - learning_rate: 5.0000e-04
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 2102.4131 - root_mean_squared_error: 45.8521 - val_loss: 953.5178 - val_root_mean_squared_error: 30.8791 - learning_rate: 5.0000e-04
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 607.3055 - root_mean_squared_error: 24.6436 - val_loss: 843.1008 - val_root_mean_squared_error: 29.0362 - learning_rate: 5.0000e-04
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2302.9512 - root_mean_squared_error: 47.9891 - val_loss: 725.3000 - val_root_mean_squared_error: 26.9314 - learning_rate: 5.0000e-04
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1267.2882 - root_mean_squared_error: 35.5990 - val_loss: 672.9861 - val_root_mean_squared_error: 25.9420 - learning_rate: 5.0000e-04
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2417.4382 - root_mean_squared_error: 49.1674 - val_loss: 628.7658 - val_root_mean_squared_error: 25.0752 - learning_rate: 5.0000e-04
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 854.3013 - root_mean_squared_error: 29.2284 - val_loss: 573.6816 - val_root_mean_squared_error: 23.9517 - learning_rate: 5.0000e-04
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 655.0042 - root_mean_squared_error: 25.5931 - val_loss: 523.5863 - val_root_mean_squared_error: 22.8820 - learning_rate: 5.0000e-04
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 750.0997 - root_mean_squared_error: 27.3879 - val_loss: 495.6649 - val_root_mean_squared_error: 22.2635 - learning_rate: 5.0000e-04
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1070.7976 - root_mean_squared_error: 32.7230 - val_loss: 449.7410 - val_root_mean_squared_error: 21.2071 - learning_rate: 5.0000e-04
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1396.6177 - root_mean_squared_error: 37.3713 - val_loss: 421.9355 - val_root_mean_squared_error: 20.5411 - learning_rate: 5.0000e-04
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 666.5012 - root_mean_squared_error: 25.8167 - val_loss: 374.6462 - val_root_mean_squared_error: 19.3558 - learning_rate: 5.0000e-04
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 294.8875 - root_mean_squared_error: 17.1723 - val_loss: 343.3748 - val_root_mean_squared_error: 18.5304 - learning_rate: 5.0000e-04
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1257.6215 - root_mean_squared_error: 35.4630 - val_loss: 315.5468 - val_root_mean_squared_error: 17.7636 - learning_rate: 5.0000e-04
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 1790.4769 - root_mean_squared_error: 42.3140 - val_loss: 282.4861 - val_root_mean_squared_error: 16.8073 - learning_rate: 5.0000e-04
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 2150.6221 - root_mean_squared_error: 46.3748 - val_loss: 255.9405 - val_root_mean_squared_error: 15.9981 - learning_rate: 5.0000e-04
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 226.4115 - root_mean_squared_error: 15.0470 - val_loss: 243.3743 - val_root_mean_squared_error: 15.6005 - learning_rate: 5.0000e-04
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 641.0463 - root_mean_squared_error: 25.3189 - val_loss: 234.0158 - val_root_mean_squared_error: 15.2976 - learning_rate: 5.0000e-04
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 887.1045 - root_mean_squared_error: 29.7843 - val_loss: 228.9097 - val_root_mean_squared_error: 15.1298 - learning_rate: 5.0000e-04
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 2463.6155 - root_mean_squared_error: 49.6348 - val_loss: 229.5249 - val_root_mean_squared_error: 15.1501 - learning_rate: 5.0000e-04
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 761.8757 - root_mean_squared_error: 27.6021 - val_loss: 231.6347 - val_root_mean_squared_error: 15.2195 - learning_rate: 5.0000e-04
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1971.9165 - root_mean_squared_error: 44.4063 - val_loss: 235.2246 - val_root_mean_squared_error: 15.3370 - learning_rate: 5.0000e-04
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 402.0694 - root_mean_squared_error: 20.0517 - val_loss: 243.8692 - val_root_mean_squared_error: 15.6163 - learning_rate: 5.0000e-04
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 742.8790 - root_mean_squared_error: 27.2558 - val_loss: 249.1489 - val_root_mean_squared_error: 15.7845 - learning_rate: 5.0000e-04
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 1526.5819 - root_mean_squared_error: 39.0715 - val_loss: 257.0602 - val_root_mean_squared_error: 16.0331 - learning_rate: 5.0000e-05
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 936.9163 - root_mean_squared_error: 30.6091 - val_loss: 264.5684 - val_root_mean_squared_error: 16.2656 - learning_rate: 5.0000e-05
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1550.9447 - root_mean_squared_error: 39.3820 - val_loss: 274.0481 - val_root_mean_squared_error: 16.5544 - learning_rate: 5.0000e-05
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 636.5473 - root_mean_squared_error: 25.2299 - val_loss: 286.5357 - val_root_mean_squared_error: 16.9274 - learning_rate: 5.0000e-05
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 541.1729 - root_mean_squared_error: 23.2631 - val_loss: 300.7635 - val_root_mean_squared_error: 17.3425 - learning_rate: 5.0000e-05
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1402.0212 - root_mean_squared_error: 37.4436 - val_loss: 307.7930 - val_root_mean_squared_error: 17.5440 - learning_rate: 5.0000e-05
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 2581.5190 - root_mean_squared_error: 50.8087 - val_loss: 320.4569 - val_root_mean_squared_error: 17.9013 - learning_rate: 5.0000e-05
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1843.1135 - root_mean_squared_error: 42.9315 - val_loss: 331.0646 - val_root_mean_squared_error: 18.1952 - learning_rate: 5.0000e-05
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2207.1729 - root_mean_squared_error: 46.9806 - val_loss: 346.0280 - val_root_mean_squared_error: 18.6018 - learning_rate: 5.0000e-05
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 1352.1915 - root_mean_squared_error: 36.7722 - val_loss: 362.4459 - val_root_mean_squared_error: 19.0380 - learning_rate: 5.0000e-05
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 835.6003 - root_mean_squared_error: 28.9068 - val_loss: 372.6849 - val_root_mean_squared_error: 19.3050 - learning_rate: 1.0000e-05
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 1729.4115 - root_mean_squared_error: 41.5862 - val_loss: 389.4882 - val_root_mean_squared_error: 19.7355 - learning_rate: 1.0000e-05
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 578.3885 - root_mean_squared_error: 24.0497 - val_loss: 407.4243 - val_root_mean_squared_error: 20.1848 - learning_rate: 1.0000e-05
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 334.6932 - root_mean_squared_error: 18.2946 - val_loss: 437.2502 - val_root_mean_squared_error: 20.9105 - learning_rate: 1.0000e-05
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1321.9467 - root_mean_squared_error: 36.3586 - val_loss: 451.3842 - val_root_mean_squared_error: 21.2458 - learning_rate: 1.0000e-05
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1377.7572 - root_mean_squared_error: 37.1182 - val_loss: 475.5252 - val_root_mean_squared_error: 21.8065 - learning_rate: 1.0000e-05
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 874.4521 - root_mean_squared_error: 29.5711 - val_loss: 500.7870 - val_root_mean_squared_error: 22.3783 - learning_rate: 1.0000e-05
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 2878.0295 - root_mean_squared_error: 53.6473 - val_loss: 507.9985 - val_root_mean_squared_error: 22.5388 - learning_rate: 1.0000e-05
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 1675.2972 - root_mean_squared_error: 40.9304 - val_loss: 526.9931 - val_root_mean_squared_error: 22.9563 - learning_rate: 1.0000e-05

# %%
# Calculamos el error RMSE:

#pred_LSTM = H.model.predict(Test_X)
pred_LSTM = my_LSTM_model2.predict(Test_X).reshape(-1)

rmse = np.sqrt(mean_squared_error(test['y'].values, pred_LSTM))

print('\nError-Modelo-FacebookProphet: RMSE: %.3f' % rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
#
# Error-Modelo-FacebookProphet: RMSE: 22.956

# %%
# Graficamos los resultados:

# Grafiquemos los resultados:

fig, ax = plt.subplots(figsize=(10, 5))
ax = plt.plot(train['ds'], train['y'], '-k')  # Datos de entrenamiento de 1949 a 1959.
ax = plt.plot(test['ds'], test['y'], '-b')    # Datos de prueba del año 1960.
ax = plt.plot(test['ds'], test['y'], '+c')    # Datos de prueba del año 1960.
ax = plt.plot(test['ds'], pred_LSTM, 'xr')  # Predicciones del modelo del año 1960.

# %% [markdown]
# **Habría que buscar la mejor arquitectura y ejecutarlo varias veces para obtener un mejor resultado.**

# %% [markdown]
# >> ## **Fin del Ejercicio de Series de Tiempo**

# %% [markdown]
# # **Parte 1: Datos sin escalar**
#
# ## 1A: Preparación de los datos

# %%
# Omitimos los warnings por el momento
import warnings
warnings.filterwarnings("ignore")

# Importamos las librerías necesarias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Importamos las métricas y modelos
from sklearn.metrics import mean_squared_error
from prophet import Prophet
from statsmodels.tsa.arima.model import ARIMA
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Si no tienes yfinance instalado, descomenta la siguiente línea
# !pip install yfinance

import yfinance as yf

# Descargamos los datos de Apple Inc. (AAPL) de los últimos 5 años
ticker_symbol = 'AAPL'
data = yf.download(ticker_symbol, period='5y')

# Utilizamos solo la columna 'Adj Close'
df = data[['Adj Close']].reset_index()

# Renombramos las columnas para facilitar el manejo
df.columns = ['ds', 'y']

# Convertimos la columna 'ds' a tipo datetime
df['ds'] = pd.to_datetime(df['ds'])

# Visualizamos los primeros registros
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                          ds          y
# 0 2019-11-05 00:00:00+00:00  62.202579
# 1 2019-11-06 00:00:00+00:00  62.229172
# 2 2019-11-07 00:00:00+00:00  62.947392
# 3 2019-11-08 00:00:00+00:00  63.119667
# 4 2019-11-11 00:00:00+00:00  63.619499

# %% [markdown]
# # **Explicación de 'Adj Close':**
#
# ### La columna 'Adj Close' (Precio de Cierre Ajustado) representa el precio de cierre de una acción después de ajustar por acciones corporativas que afectan su precio, como dividendos, divisiones de acciones (splits) o emisiones de derechos. Este ajuste proporciona una visión más precisa del rendimiento histórico de una acción, reflejando el valor real que un inversor habría obtenido si hubiera mantenido la acción durante ese período.

# %% [markdown]
# # **División de los datos en Train y Test**

# %%
# Dividimos los datos en Train y Test
# Usaremos los últimos 20 precios para Test
train = df.iloc[:-20]
test = df.iloc[-20:]

print("Tamaño del conjunto de entrenamiento:", train.shape)
print("Tamaño del conjunto de prueba:", test.shape)
# Out:
# Tamaño del conjunto de entrenamiento: (1238, 2)
# Tamaño del conjunto de prueba: (20, 2)

# %% [markdown]
# # **1B: Modelo ingenuo**
#
# ### El modelo ingenuo (Naive) utiliza el valor más reciente para predecir el siguiente valor. Es un punto de partida simple para comparar con otros modelos.

# %%
# Obtenemos los valores históricos de entrenamiento
history = [x for x in train['y']]
predictions_naive = []

# Realizamos las predicciones
for i in range(len(test)):
    yhat = history[-1]
    predictions_naive.append(yhat)
    obs = test.iloc[i]['y']
    history.append(obs)
    print(f'>Esperado: {obs:.2f}, Predicción: {yhat:.2f}')

# Calculamos el RMSE
rmse_naive = np.sqrt(mean_squared_error(test['y'], predictions_naive))
print(f'\nError del Modelo Ingenuo (RMSE): {rmse_naive:.3f}')
# Out:
# >Esperado: 225.77, Predicción: 221.69
# >Esperado: 229.54, Predicción: 225.77
# >Esperado: 229.04, Predicción: 229.54
# >Esperado: 227.55, Predicción: 229.04
# >Esperado: 231.30, Predicción: 227.55
# >Esperado: 233.85, Predicción: 231.30
# >Esperado: 231.78, Predicción: 233.85
# >Esperado: 232.15, Predicción: 231.78
# >Esperado: 235.00, Predicción: 232.15
# >Esperado: 236.48, Predicción: 235.00
# >Esperado: 235.86, Predicción: 236.48
# >Esperado: 230.76, Predicción: 235.86
# >Esperado: 230.57, Predicción: 230.76
# >Esperado: 231.41, Predicción: 230.57
# >Esperado: 233.40, Predicción: 231.41
# >Esperado: 233.67, Predicción: 233.40
# >Esperado: 230.10, Predicción: 233.67
# >Esperado: 225.91, Predicción: 230.10
# >Esperado: 222.91, Predicción: 225.91
# >Esperado: 222.01, Predicción: 222.91
#
# Error del Modelo Ingenuo (RMSE): 2.645

# %% [markdown]
# # **Gráfico de Predicciones vs Datos Reales**

# %%
plt.figure(figsize=(12,6))
plt.plot(train['ds'], train['y'], label='Entrenamiento')
plt.plot(test['ds'], test['y'], label='Prueba', color='green')
plt.plot(test['ds'], predictions_naive, label='Predicción Naive', color='red', linestyle='--')
plt.xlabel('Fecha')
plt.ylabel('Precio de Cierre Ajustado')
plt.title('Modelo Ingenuo - Predicciones vs Datos Reales')
plt.legend()
plt.show()

# %% [markdown]
# # **1C: Modelo ARIMA**
#
# ### ARIMA es un modelo estadístico que utiliza componentes autorregresivas y de media móvil para modelar series de tiempo.

# %%
from statsmodels.tsa.stattools import adfuller

# Verificamos la estacionariedad de la serie
result = adfuller(train['y'])
print('Estadístico ADF:', result[0])
print('Valor p:', result[1])

# Si la serie no es estacionaria, la diferenciamos
train_diff = train['y'].diff().dropna()

# Ajustamos el modelo ARIMA
model_arima = ARIMA(train['y'], order=(5,1,0))
model_arima_fit = model_arima.fit()

# Realizamos las predicciones
forecast_arima = model_arima_fit.forecast(steps=len(test))
rmse_arima = np.sqrt(mean_squared_error(test['y'], forecast_arima))
print(f'\nError del Modelo ARIMA (RMSE): {rmse_arima:.3f}')
# Out:
# Estadístico ADF: -1.3024290642123098
# Valor p: 0.6280602823976479
#
# Error del Modelo ARIMA (RMSE): 9.517

# %% [markdown]
# # **Gráfico de Predicciones vs Datos Reales**

# %%
plt.figure(figsize=(12,6))
plt.plot(train['ds'], train['y'], label='Entrenamiento')
plt.plot(test['ds'], test['y'], label='Prueba', color='green')
plt.plot(test['ds'], forecast_arima, label='Predicción ARIMA', color='red', linestyle='--')
plt.xlabel('Fecha')
plt.ylabel('Precio de Cierre Ajustado')
plt.title('Modelo ARIMA - Predicciones vs Datos Reales')
plt.legend()
plt.show()

# %% [markdown]
# # **1D: Modelo Prophet**
#
# ### Prophet es una herramienta de Facebook para el pronóstico de series de tiempo que maneja automáticamente componentes como tendencias y estacionalidades.

# %%
# Eliminamos la información de zona horaria
train['ds'] = train['ds'].dt.tz_localize(None)
test['ds'] = test['ds'].dt.tz_localize(None)

# Ajustamos el modelo Prophet
model_prophet = Prophet(daily_seasonality=True)
model_prophet.fit(train)

# Realizamos las predicciones
future = model_prophet.make_future_dataframe(periods=len(test))
forecast_prophet = model_prophet.predict(future)

# Extraemos las predicciones correspondientes al conjunto de prueba
predictions_prophet = forecast_prophet.iloc[-len(test):]['yhat']
rmse_prophet = np.sqrt(mean_squared_error(test['y'], predictions_prophet))
print(f'\nError del Modelo Prophet (RMSE): {rmse_prophet:.3f}')
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp__ib1p1x/dk48hxne.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp__ib1p1x/x9xb_yxt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86881', 'data', 'file=/tmp/tmp__ib1p1x/dk48hxne.json', 'init=/tmp/tmp__ib1p1x/x9xb_yxt.json', 'output', 'file=/tmp/tmp__ib1p1x/prophet_modelpgi07ly4/prophet_model-20241105045201.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:52:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:52:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Error del Modelo Prophet (RMSE): 8.180

# %% [markdown]
# # **Gráfico de Predicciones vs Datos Reales**

# %%
plt.figure(figsize=(12,6))
plt.plot(train['ds'], train['y'], label='Entrenamiento')
plt.plot(test['ds'], test['y'], label='Prueba', color='green')
plt.plot(test['ds'], predictions_prophet, label='Predicción Prophet', color='red', linestyle='--')
plt.xlabel('Fecha')
plt.ylabel('Precio de Cierre Ajustado')
plt.title('Modelo Prophet - Predicciones vs Datos Reales')
plt.legend()
plt.show()

# %% [markdown]
# # **1E: Modelo LSTM**
#
# ### Las redes neuronales LSTM son capaces de aprender dependencias a largo plazo en secuencias de datos.

# %%
# Preparación de los datos para LSTM
from sklearn.preprocessing import MinMaxScaler

# Convertimos los datos a numpy arrays
train_lstm = train['y'].values
test_lstm = test['y'].values

# Reshape para aplicar el escalador
train_lstm = train_lstm.reshape(-1, 1)
test_lstm = test_lstm.reshape(-1, 1)

# Escalamos los datos entre 0 y 1
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train_lstm)

# Creamos las secuencias de entrenamiento
X_train = []
y_train = []
for i in range(60, len(train_scaled)):
    X_train.append(train_scaled[i-60:i, 0])
    y_train.append(train_scaled[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

# Reshape para LSTM [samples, time_steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# Construimos el modelo LSTM
model_lstm = Sequential()
model_lstm.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model_lstm.add(Dropout(0.2))
model_lstm.add(LSTM(units=50))
model_lstm.add(Dropout(0.2))
model_lstm.add(Dense(1))

# Compilamos el modelo
model_lstm.compile(optimizer='adam', loss='mean_squared_error')

# Entrenamos el modelo
model_lstm.fit(X_train, y_train, epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 0.1039
# Epoch 2/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0060
# Epoch 3/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0042
# Epoch 4/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0040
# Epoch 5/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0043
# Epoch 6/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0038
# Epoch 7/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0041
# Epoch 8/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0035
# Epoch 9/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0035
# Epoch 10/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0036
# Epoch 11/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0035
# Epoch 12/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0034
# Epoch 13/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0031
# Epoch 14/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0031
# Epoch 15/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0030
# Epoch 16/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0038
# Epoch 17/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0029
# Epoch 18/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0027
# Epoch 19/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.0031
# Epoch 20/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0027

# %% [markdown]
# # Realizamos las predicciones

# %%
# Preparación de los datos de prueba
total_data = pd.concat((train['y'], test['y']), axis=0)
inputs = total_data[len(total_data) - len(test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = scaler.transform(inputs)

X_test = []
for i in range(60, 60 + len(test)):
    X_test.append(inputs[i-60:i, 0])

X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Predicciones
predictions_lstm = model_lstm.predict(X_test)
predictions_lstm = scaler.inverse_transform(predictions_lstm)

# Calculamos el RMSE
rmse_lstm = np.sqrt(mean_squared_error(test['y'], predictions_lstm))
print(f'\nError del Modelo LSTM (RMSE): {rmse_lstm:.3f}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Error del Modelo LSTM (RMSE): 4.732

# %% [markdown]
# # **Gráfico de Predicciones vs Datos Reales**

# %%
plt.figure(figsize=(12,6))
plt.plot(train['ds'], train['y'], label='Entrenamiento')
plt.plot(test['ds'], test['y'], label='Prueba', color='green')
plt.plot(test['ds'], predictions_lstm, label='Predicción LSTM', color='red', linestyle='--')
plt.xlabel('Fecha')
plt.ylabel('Precio de Cierre Ajustado')
plt.title('Modelo LSTM - Predicciones vs Datos Reales')
plt.legend()
plt.show()
